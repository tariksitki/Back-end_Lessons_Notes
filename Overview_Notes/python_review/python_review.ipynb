# %%
a = "   This is multi linerrrrr"

print(a.count("i"))
# Out:
# 4

# %%
a.strip("r")
print(a)
## strip orijinali degistirmez

print(a.strip("r"))
# Out:
#    This is multi linerrrrr
#    This is multi line

# %%
7 // 2
# Out:
# 3

# %%
list1 = ["Apple", 1, 3.5, True, [1, 3], {"Ready": "yes"}]

list1.append("Apple")

print(list1.index("Apple"))

## eger ilk index i atlamasini istersek
print(list1.index("Apple", 1))
# Out:
# 0
# 6

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list1 + list2
# Out:
# ['a', 'b', 'c', 1, 2, 3]
